# %% [markdown]
# ## ladestation data

# %%
import pandas as pd

# Read the CSV file
df_ladestation = pd.read_csv("../02_data/01_original_data/ladestationFactTable.csv", sep= ";")

# Display the first few rows of the data

df_ladestation.info()
df_ladestation.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94069 entries, 0 to 94068
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ladestation_id               94069 non-null  int64
#  1   Betreiber                    94069 non-null  object
#  2   BetreiberBereinigt           94068 non-null  object
#  3   BetreiberKategorie           94069 non-null  object
#  4   Strasse                      94069 non-null  object
#  5   Hausnummer                   94069 non-null  object
#  6   Adresszusatz                 15744 non-null  object
#  7   PLZ                          94069 non-null  int64
#  8   Ort                          94069 non-null  object
#  9   Bundesland                   94069 non-null  object
#  10  KreisKreisfreieStadt         94069 non-null  object
#  11  Gemeinde                     94069 non-null  object
#  12  ARS                          94069 non-null  int64
# ...

# %%
df_ladestation.shape
# Out:
# (94069, 24)
